# %% [markdown]
# <a href="https://colab.research.google.com/github/harshdarji23/YaayBnb/blob/master/Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# package imports
#basics
import numpy as np
import pandas as pd

#viz
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.gridspec as gridspec 
import matplotlib.gridspec as gridspec 


#settings

color = sns.color_palette()
sns.set_style("dark")
pd.set_option('display.max_columns', None)

# %matplotlib inline

# %% [markdown]
# From a local drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1e3d35de-3289-4d81-8e35-aa81a9671cbd" name="files[]" multiple disabled />
#      <output id="result-1e3d35de-3289-4d81-8e35-aa81a9671cbd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving neighbourhoods.geojson to neighbourhoods.geojson

# %%
airbnb=pd.read_csv('Airbnb_cleaned (1).csv',index_col=False)

# %%
# Data Exploration

# %%
airbnb.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
airbnb.head(2)
# Out:
#      id  host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0  2595     2845           Manhattan       Midtown  40.75362  -73.98377
# 1  3831     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0  Entire home/apt    225              10                 48
# 1  Entire home/apt     89               1                295
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.39                               1                 1
# 1               4.67                               1                 1
#
#                                          description  accommodates
# 0  Beautiful, spacious skylit studio in the heart...             1
# 1  Urban retreat: enjoy 500 s.f. floor in 1899 br...             3

# %%
# NYC is an expensive city so let's check average price of a room here: 
# From below we see the average price of a room in NYC is $158

# %%
airbnb.describe().T
# Out:
#                                   count          mean           std  \
# id                              49567.0  2.109428e+07  1.237033e+07
# host_id                         49567.0  7.773996e+07  9.027738e+07
# latitude                        49567.0  4.072880e+01  5.478862e-02
# longitude                       49567.0 -7.395108e+01  4.724706e-02
# price                           49567.0  1.586312e+02  3.504252e+02
# minimum_nights                  49567.0  7.556096e+00  2.246559e+01
# number_of_reviews               49567.0  2.524226e+01  4.769319e+01
# reviews_per_month               49567.0  1.128748e+00  1.621305e+00
# calculated_host_listings_count  49567.0  7.433635e+00  3.308616e+01
# availability_365                49567.0  1.123160e+02  1.357825e+02
# accommodates                    49567.0  2.870357e+00  1.906486e+00
#
#                                        min           25%           50%  \
# id                              2595.00000  9.976678e+06  2.123326e+07
# host_id                         2438.00000  8.715723e+06  3.487321e+07
# latitude                          40.49979  4.068968e+01  4.072290e+01
# longitude                        -74.24787 -7.398298e+01 -7.395519e+01
# price                              0.00000  6.900000e+01  1.060000e+02
# minimum_nights                     1.00000  1.000000e+00  3.000000e+00
# number_of_reviews                  0.00000  1.000000e+00  6.000000e+00
# reviews_per_month                  0.00000  4.000000e-02  3.800000e-01
# calculated_host_listings_count     1.00000  1.000000e+00  1.000000e+00
# availability_365                   0.00000  0.000000e+00  4.000000e+01
# accommodates                       1.00000  2.000000e+00  2.000000e+00
#
#                                          75%           max
# id                              3.230379e+07  4.058402e+07
# host_id                         1.265654e+08  3.143682e+08
# latitude                        4.076299e+01  4.091686e+01
# longitude                      -7.393470e+01 -7.371299e+01
# price                           1.750000e+02  1.000000e+04
# minimum_nights                  5.000000e+00  1.250000e+03
# number_of_reviews               2.600000e+01  6.750000e+02
# reviews_per_month               1.670000e+00  5.263000e+01
# calculated_host_listings_count  2.000000e+00  3.100000e+02
# availability_365                2.250000e+02  3.650000e+02
# accommodates                    4.000000e+00  2.500000e+01

# %%
# let's check correlation
# Most of the attributes are not correlated , but there's some correlation between num of reviews and reviews per month

# %%
airbnb.corr().style.background_gradient(cmap='RdPu')
# Out:
# <style  type="text/css" >
#     #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col0 {
#             background-color:  #49006a;
#             color:  #f1f1f1;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col1 {
#             background-color:  #d32992;
#             color:  #f1f1f1;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col2 {
#             background-color:  #fef1ed;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col3 {
#             background-color:  #fcd1cd;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col4 {
#             background-color:  #fddfdc;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col5 {
#             background-color:  #fde1de;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col6 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col7 {
#             background-color:  #fbb8bc;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col8 {
#             background-color:  #fcceca;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col9 {
#             background-color:  #fdddd9;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row0_col10 {
#             background-color:  #fde5e2;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col0 {
#             background-color:  #c21688;
#             color:  #f1f1f1;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col1 {
#             background-color:  #49006a;
#             color:  #f1f1f1;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col2 {
#             background-color:  #feebe8;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col3 {
#             background-color:  #fcccc7;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col4 {
#             background-color:  #fddcd8;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col5 {
#             background-color:  #fde0dd;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col6 {
#             background-color:  #fddfdc;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col7 {
#             background-color:  #fbb3bb;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col8 {
#             background-color:  #fcd0cc;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col9 {
#             background-color:  #fcc7c3;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row1_col10 {
#             background-color:  #fde1de;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col0 {
#             background-color:  #fcc9c4;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col1 {
#             background-color:  #fdddd9;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col2 {
#             background-color:  #49006a;
#             color:  #f1f1f1;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col3 {
#             background-color:  #fdd7d3;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col4 {
#             background-color:  #fde0dd;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col5 {
#             background-color:  #fdddd9;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col6 {
#             background-color:  #fcccc7;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col7 {
#             background-color:  #fde6e2;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col8 {
#             background-color:  #fde1de;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col9 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row2_col10 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col0 {
#             background-color:  #fbb2ba;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col1 {
#             background-color:  #fcc7c3;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col2 {
#             background-color:  #fde2df;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col3 {
#             background-color:  #49006a;
#             color:  #f1f1f1;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col4 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col5 {
#             background-color:  #feebe7;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col6 {
#             background-color:  #fbbbbd;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col7 {
#             background-color:  #fcc4c0;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col8 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col9 {
#             background-color:  #fee8e5;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row3_col10 {
#             background-color:  #fef1ed;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col0 {
#             background-color:  #fcc2bf;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col1 {
#             background-color:  #fdd7d4;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col2 {
#             background-color:  #feebe7;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col3 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col4 {
#             background-color:  #49006a;
#             color:  #f1f1f1;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col5 {
#             background-color:  #fdddd9;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col6 {
#             background-color:  #fcd0cc;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col7 {
#             background-color:  #fee9e5;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col8 {
#             background-color:  #fde1de;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col9 {
#             background-color:  #feebe7;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row4_col10 {
#             background-color:  #fcc2bf;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row5_col0 {
#             background-color:  #fcc8c3;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row5_col1 {
#             background-color:  #fddfdc;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row5_col2 {
#             background-color:  #feebe7;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row5_col3 {
#             background-color:  #feeeea;
#             color:  #000000;
#         }    #T_a39eeece_5f69_11ea_ab31_0242ac1c0002row5_col4 {
#             background-color:  #fde0dd;
#             color:  #000000

# %%
# Manhattan is called heart of NYC so let's explore this neighborhood

# %%
sns.countplot(airbnb['neighbourhood_group'], palette="bright")#hue=airbnb['neighbourhood_group'])
fig = plt.gcf()
fig.set_size_inches(12,7)
plt.title('Share of New York',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Share of New York')

# %%
# clearly, Manhattan and Brooklyn have more rentals, now let's visualize them on a map

# %%
import sys
#sys.setrecursionlimit(10000)
#to make the interactive maps
import folium
from folium.plugins import FastMarkerCluster
#import geopandas as gpd
#from branca.colormap import LinearColormap

# %%
lats =airbnb['latitude'].tolist()
lons = airbnb['longitude'].tolist()
locations = list(zip(lats, lons))

map1 = folium.Map(location=[40.7128,-74.0060], zoom_start=11)
FastMarkerCluster(data=locations).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def generateBaseMap(default_location=[40.693943, -73.985880], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# %%
from folium.plugins import HeatMap
df_copy = airbnb[['latitude','longitude']].copy()
df_copy['count'] = 1
base_map = generateBaseMap()
HeatMap(data=df_copy[['latitude', 'longitude', 'count']].values.tolist(), radius=8,gradient={0.2:'blue',0.4:'purple',0.6:'yellow',1.0:'red'}, max_zoom=11).add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# of course Manhattan has a lot of listings but it's expensive as well, let's check pricing for each neighborhood

# %%
plt.figure(figsize=(10,6))
sns.distplot(airbnb[airbnb.neighbourhood_group=='Manhattan'].price,color='maroon',hist=False,label='Manhattan')
sns.distplot(airbnb[airbnb.neighbourhood_group=='Brooklyn'].price,color='black',hist=False,label='Brooklyn')
sns.distplot(airbnb[airbnb.neighbourhood_group=='Queens'].price,color='green',hist=False,label='Queens')
sns.distplot(airbnb[airbnb.neighbourhood_group=='Staten Island'].price,color='blue',hist=False,label='Staten Island')
sns.distplot(airbnb[airbnb.neighbourhood_group=='Long Island'].price,color='lavender',hist=False,label='Long Island')
plt.title('Borough wise price distribution for price<1500')
plt.xlim(0,1500)
plt.show()

# %%
plt.style.use('fivethirtyeight')
ng = airbnb[airbnb.price <500]
plt.figure(figsize=(10,6))
sns.boxplot(y="price",x ='neighbourhood_group' ,data = ng)
plt.title("neighbourhood_group price distribution < 500")
plt.show()

# %%
feq = airbnb[airbnb['accommodates']==2]
feq = feq.groupby('neighbourhood')['price'].mean().sort_values(ascending=True)
#feq.plot.barh(figsize=(10, 8), color='b', width=1)
#plt.title("Average daily price for a 2-persons accommodation", fontsize=20)
#plt.xlabel('Average daily price ($$)', fontsize=12)
#plt.ylabel("")
#plt.show()

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Using cached https://files.pythonhosted.org/packages/83/c5/3cf9cdc39a6f2552922f79915f36b45a95b71fd343cfc51170a5b6ddb6e8/geopandas-0.7.0-py2.py3-none-any.whl
# Requirement already satisfied: fiona in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.8.13.post1)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (2.5.0)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (0.25.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.7.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.12.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (19.3.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (0.5.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: munch in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (1.17.5)
# Installing collected packages: geopandas
# Successfully installed geopandas-0.7.0

# %%
pip install https://github.com/pyinstaller/pyinstaller/archive/develop.zip
# Out:
# Collecting https://github.com/pyinstaller/pyinstaller/archive/develop.zip
#   Downloading https://github.com/pyinstaller/pyinstaller/archive/develop.zip
#      \ 22.2MB 19.3MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting altgraph
#   Downloading https://files.pythonhosted.org/packages/ee/3d/bfca21174b162f6ce674953f1b7a640c1498357fa6184776029557c25399/altgraph-0.17-py2.py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from PyInstaller==4.0.dev0+96897fc78d) (45.2.0)
# Building wheels for collected packages: PyInstaller
#   Building wheel for PyInstaller (PEP 517) ... done
#   Created wheel for PyInstaller: filename=PyInstaller-4.0.dev0+96897fc78d-cp36-none-any.whl size=2918691 sha256=872fd1aaf3846a90f92703e2d4979be4602a45e73d80b65a2aa5101e67514f44
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9fw8ouif/wheels/1e/5b/0a/b7b241e8886f8f6d4c41177dd91cdb275f0cda6cd9dde93269
# Successfully built PyInstaller
# Installing collected packages: altgraph, PyInstaller
# Successfully installed PyInstaller-4.0.dev0+96897fc78d altgraph-0.17

# %%
import geopandas as gpd
from branca.colormap import LinearColormap
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-67819bae140e> in <module>()
# ----> 1 import geopandas as gpd
#       2 from branca.colormap import LinearColormap
#
# /usr/local/lib/python3.6/dist-packages/geopandas/__init__.py in <module>()
#       3 from geopandas.array import _points_from_xy as points_from_xy  # noqa
#       4
# ----> 5 from geopandas.io.file import read_file  # noqa
#       6 from geopandas.io.sql import read_postgis  # noqa
#       7 from geopandas.tools import sjoin  # noqa
#
# /usr/local/lib/python3.6/dist-packages/geopandas/io/file.py in <module>()
#       4 import pandas as pd
#       5
# ----> 6 import fiona
#       7 from shapely.geometry import mapping
#       8 from shapely.geometry.base import BaseGeometry
#
# /usr/local/lib/python3.6/dist-packages/fiona/__init__.py in <module>()
#      82     os.environ["PATH"] = os.environ["PATH"] + ";" + libdir
#      83
# ---> 84 from fiona.collection import BytesCollection, Collection
#      85 from fiona.drvsupport import supported_drivers
#      86 from fiona.env import ensure_env_with_credentials, Env
#
# /usr/local/lib/python3.6/dist-packages/fiona/collection.py in <module>()
#       7
#       8 from fiona import compat, vfs
# ----> 9 from fiona.ogrext import Iterator, ItemsIterator, KeysIterator
#      10 from fiona.ogrext import Session, WritingSession
#      11 from fiona.ogrext import buffer_to_virtual_file, remove_virtual_file, GEOMETRY_TYPES
#
# fiona/ogrext.pyx in init fiona.ogrext()
#
# AttributeError: type object 'fiona.ogrext.FeatureBuilder' has no attribute '__reduce_cython__'

# %%
import json

# %%
adam = json.read_file("neighbourhoods.geojson")
feq = pd.DataFrame([feq])
feq = feq.transpose()
adam = pd.merge(adam, feq, on='neighbourhood', how='left')
adam.rename(columns={'price': 'average_price'}, inplace=True)
adam.average_price = adam.average_price.round(decimals=0)
map_dict = adam.set_index('neighbourhood')['average_price'].to_dict()
color_scale = LinearColormap(['yellow','red'], vmin = min(map_dict.values()), vmax = max(map_dict.values()))

def get_color(feature):
    value = map_dict.get(feature['properties']['neighbourhood'])
    return color_scale(value)
map3 = folium.Map(location=[40.693943, -73.985880], zoom_start=11)
folium.GeoJson(data=adam,
               name='New York',
               tooltip=folium.features.GeoJsonTooltip(fields=['neighbourhood', 'average_price'],
                                                      labels=True,
                                                      sticky=False),
               style_function= lambda feature: {
                   'fillColor': get_color(feature),
                   'color': 'black',
                   'weight': 1,
                   'dashArray': '5, 5',
                   'fillOpacity':0.5
                   },
               highlight_function=lambda feature: {'weight':3, 'fillColor': get_color(feature), 'fillOpacity': 0.8}).add_to(map3)
map3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-b5be4b674ffa> in <module>()
# ----> 1 adam = json.read_file("neighbourhoods.geojson")
#       2 feq = pd.DataFrame([feq])
#       3 feq = feq.transpose()
#       4 adam = pd.merge(adam, feq, on='neighbourhood', how='left')
#       5 adam.rename(columns={'price': 'average_price'}, inplace=True)
#
# AttributeError: module 'json' has no attribute 'read_file'

# %%
# we have neighborhoods inside neighborhood group, let's explore them

# %%
airbnb.neighbourhood.value_counts()
# Out:
# Bedford-Stuyvesant            3904
# Williamsburg                  3879
# Harlem                        2700
# Bushwick                      2449
# Hell's Kitchen                2001
# Upper West Side               1958
# East Village                  1857
# Upper East Side               1769
# Crown Heights                 1600
# Midtown                       1502
# Chelsea                       1141
# East Harlem                   1136
# Greenpoint                    1095
# Lower East Side                932
# Washington Heights             927
# Astoria                        917
# West Village                   765
# Financial District             729
# Flatbush                       623
# Clinton Hill                   576
# Long Island City               546
# Prospect-Lefferts Gardens      529
# East Flatbush                  509
# Murray Hill                    505
# Park Slope                     501
# Flushing                       491
# Fort Greene                    477
# Kips Bay                       442
# Ridgewood                      426
# Sunset Park                    406
#                               ...
# New Brighton                     4
# Holliswood                       4
# Westerleigh                      4
# Todt Hill                        4
# Co-op City                       4
# Spuyten Duyvil                   4
# Arden Heights                    4
# New Springville                  4
# Bull's Head                      3
# Neponsit                         3
# Castle Hill                      3
# Castleton Corners                3
# Oakwood                          3
# Eltingville                      3
# Gerritsen Beach                  2
# Graniteville                     2
# Silver Lake                      2
# Huguenot                         2
# Richmondtown                     2
# Rossville                        2
# Lighthouse Hill                  2
# Howland Hook                     2
# Prince's Bay                     2
# Breezy Point                     2
# West Farms                       2
# New Dorp                         1
# Country Club                     1
# Woodrow                          1
# Bay Terrace, Staten Island       1
# Fort Wadsworth                   1
# Name: neighbourhood, Length: 222, dtype: int64
